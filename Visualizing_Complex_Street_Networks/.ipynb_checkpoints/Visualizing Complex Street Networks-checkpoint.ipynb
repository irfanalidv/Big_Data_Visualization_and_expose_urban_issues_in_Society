# %%
import osmnx as ox
ox.plot_graph(ox.graph_from_place('Modena, Italy'))
# Out:
# (<matplotlib.figure.Figure at 0x7f5d1cc20e10>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f5d1cc269b0>)

# %%
import osmnx as ox
city = ox.gdf_from_place('Berkeley, CA')
ox.plot_shape(ox.project_gdf(city))
# Out:
# (<matplotlib.figure.Figure at 0x7f320137e828>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3200ee0518>)

# %%
place1 = ox.gdf_from_place('Manhattan, New York City, New York, USA')
place2 = ox.gdf_from_place('Cook County, Illinois')
place3 = ox.gdf_from_place('Iowa, USA')
place4 = ox.gdf_from_place('Bolivia')

# %%
places = ox.gdf_from_places(['Botswana', 'Zambia', 'Zimbabwe'])
places = ox.project_gdf(places)
ox.save_gdf_shapefile(places)
ox.plot_shape(ox.project_gdf(places))
# Out:
# (<matplotlib.figure.Figure at 0x7f3200ca1e80>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f3202e499e8>)

# %%
#Street Network from bounding box
G = ox.graph_from_bbox(37.79, 37.78, -122.41, -122.43, network_type='drive')
G_projected = ox.project_graph(G)
ox.plot_graph(G_projected)
# Out:
# (<matplotlib.figure.Figure at 0x7f5d1cbfd048>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f5d1cc060f0>)

# %%
#street network from lat-long point
G = ox.graph_from_point((37.79, -122.41), distance=750, network_type='all')
ox.plot_graph(G)
# Out:
# (<matplotlib.figure.Figure at 0x7f5d1a2327f0>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f5d1a62a470>)

# %%
#street network from address
G = ox.graph_from_address('350 5th Ave, New York, NY', network_type='drive')
ox.plot_graph(G)
# Out:
# (<matplotlib.figure.Figure at 0x7f5d192c1eb8>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f5d192c1390>)
